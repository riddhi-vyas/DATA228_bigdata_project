# %%
import os
os.environ['PYSPARK_PYTHON'] = '/Users/priyasuresh/.pyenv/shims/python3.10'
os.environ['PYSPARK_DRIVER_PYTHON'] = '/Users/priyasuresh/.pyenv/shims/python3.10'

# %%
# !which python
# Out:
# /Users/priyasuresh/.pyenv/versions/3.10.4/bin/python

# %%
import numpy as np
import hashlib
from pyspark.sql.functions import col, from_json
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from scipy.stats import laplace  # Import Laplace distribution for differential privacy

# Define SimpleFilter class
class SimpleFilter:
    def __init__(self, size, hash_count):
        self.size = size
        self.hash_count = hash_count
        self.bit_array = np.zeros(size, dtype=np.bool_)

    def _hash(self, item, seed):
        hash_val = int(hashlib.md5(item.encode('utf-8')).hexdigest(), 16)
        return (hash_val + seed) % self.size

    def add(self, item):
        for seed in range(self.hash_count):
            index = self._hash(item, seed)
            self.bit_array[index] = True

    def check(self, item):
        for seed in range(self.hash_count):
            index = self._hash(item, seed)
            if not self.bit_array[index]:
                return False
        return True

from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, DoubleType
from scipy.stats import laplace

# Initialize Spark session
spark = SparkSession \
    .builder \
    .appName("StreamingWithBloomFilter") \
    .master("local[*]") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.1") \
    .getOrCreate()

# Define the schema of the message
messageSchema = StructType([
    StructField("symbol_id", StringType()),
    StructField("sequence", StringType()),
    StructField("time_exchange", TimestampType()),
    StructField("time_coinapi", TimestampType()),
    StructField("uuid", StringType()),
    StructField("price", DoubleType()),
    StructField("size", DoubleType()),
    StructField("taker_side", StringType())
])

# Subscribe to multiple topics
topic_names = "bitstamp_btc_usd,bitfinex_btc_usd,kraken_btc_usd"

# Create a streaming DataFrame that reads from the topics
df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", topic_names) \
    .load()

# Deserialize the JSON data and apply the schema
value_df = df.select(from_json(col("value").cast("string"), messageSchema).alias("data")).select("data.*")

# Initialize the Bloom Filter
bloom_filter = SimpleFilter(10000, 3)

# Function to add Laplacian noise for differential privacy
def add_laplace_noise(data, epsilon=1.0, sensitivity=1):
    try:
        # Convert data to float and then add Laplace noise
        data_float = float(data)
        scale = sensitivity / epsilon
        noise = laplace.rvs(scale=scale, size=1)[0]
        return str(data_float + noise)  # Convert back to string after adding noise
    except ValueError:
        # If data cannot be converted to float (e.g., UUID), return the original value
        return data

# Define process_batch function with differential privacy
def process_batch(batch_df, batch_id):
    # Convert to Pandas DataFrame for easier manipulation
    pandas_df = batch_df.toPandas()
    
    # Apply differential privacy to each UUID
    pandas_df['uuid'] = pandas_df['uuid'].apply(add_laplace_noise)
    
    # Apply the Bloom Filter to each row
    for index, row in pandas_df.iterrows():
        uuid = row['uuid']
        if not bloom_filter.check(uuid):
            bloom_filter.add(uuid)  # Use add method to insert UUID into the Bloom filter
            # Process the row since it's not a duplicate
            print(row)

# Apply the function to each micro-batch
query = value_df.writeStream.foreachBatch(process_batch).start()

# Wait for the stream to finish
query.awaitTermination()
# Out:
# 24/03/29 14:17:23 WARN Utils: Your hostname, Priyas-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.68.59 instead (on interface en0)
# 24/03/29 14:17:23 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/priyasuresh/.ivy2/cache
# The jars for the packages stored in: /Users/priyasuresh/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-eb675797-7adb-4014-826a-69138f403342;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.1 in central
# 	found org.apache.kafka#kafka-clients;3.4.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.3 in central
# 	found org.slf4j#slf4j-api;2.0.7 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# :: resolution report :: resolve 193ms :: artifacts dl 6ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.7 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-eb675797-7adb-4014-826a-69138f403342
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/3ms)
# 24/03/29 14:17:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/29 14:17:25 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/9j/0m5g2l6d03z4pd5y6pt7xh1h0000gn/T/temporary-416c58cf-8f0f-4514-a12f-c9fdde354871. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/03/29 14:17:25 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/03/29 14:17:25 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25181
# time_exchange              2024-03-29 14:17:28.201206
# time_coinapi               2024-03-29 14:17:28.221169
# uuid             5f9d98cd-fe5d-45be-92bc-fa9cfbe11f37
# price                                         69580.0
# size                                             0.05
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5577
# time_exchange              2024-03-29 14:17:28.538023
# time_coinapi               2024-03-29 14:17:28.565928
# uuid             2ab89a35-e8bd-4eed-b2f2-c16a5e39215a
# price                                         69505.0
# size                                         0.001659
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25183
# time_exchange              2024-03-29 14:17:29.330456
# time_coinapi               2024-03-29 14:17:29.350360
# uuid             5c41816a-3495-4ddd-8ef9-818db5991d4c
# price                                         69580.0
# size                                             0.05
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25185
# time_exchange              2024-03-29 14:17:30.550939
# time_coinapi               2024-03-29 14:17:30.576142
# uuid             b2150eea-4930-4e16-b8b2-3d6757eb5928
# price                                         69580.0
# size                                              0.1
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25187
# time_exchange              2024-03-29 14:17:33.115117
# time_coinapi               2024-03-29 14:17:33.138531
# uuid             f1f181c1-5c16-49aa-9d19-05cfc79484a3
# price                                         69580.1
# size                                          0.00069
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25189
# time_exchange              2024-03-29 14:17:34.670887
# time_coinapi               2024-03-29 14:17:34.692299
# uuid             1815aa43-df40-491a-8949-3a8c41489568
# price                                         69580.1
# size                                         0.000147
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25191
# time_exchange              2024-03-29 14:17:41.642873
# time_coinapi               2024-03-29 14:17:41.667961
# uuid             380e8c59-23c1-49ed-af93-16f38932fcc4
# price                                         69580.1
# size                                         0.000636
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43316
# time_exchange              2024-03-29 14:17:47.496000
# time_coinapi               2024-03-29 14:17:47.528505
# uuid             e7529e90-c7cd-459f-b166-fe332de387f5
# price                                         69510.0
# size                                         0.000044
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43318
# time_exchange              2024-03-29 14:17:47.496000
# time_coinapi               2024-03-29 14:17:47.528637
# uuid             79c607c6-9115-4a98-abf3-fb6313e0241f
# price                                         69510.0
# size                                         0.003552
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25193
# time_exchange              2024-03-29 14:17:48.247205
# time_coinapi               2024-03-29 14:17:48.267062
# uuid             62e16cd7-6211-4d21-a26b-db5f9b970543
# price                                         69580.0
# size                                          0.01568
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18263
# time_exchange              2024-03-29 14:17:48.849000
# time_coinapi               2024-03-29 14:17:48.878439
# uuid             fc9e6bf3-a39d-4d79-a1ca-255a5cafeefe
# price                                         69552.0
# size                                          0.11402
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5579
# time_exchange              2024-03-29 14:17:49.213182
# time_coinapi               2024-03-29 14:17:49.240205
# uuid             435544b8-f985-46f9-8c3d-4b4f370a2de7
# price                                         69505.0
# size                                          0.00192
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5581
# time_exchange              2024-03-29 14:17:49.213182
# time_coinapi               2024-03-29 14:17:49.240205
# uuid             1b93c15b-84a6-480e-a3ae-fee795f0a971
# price                                         69491.6
# size                                          0.00076
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25195
# time_exchange              2024-03-29 14:17:51.010812
# time_coinapi               2024-03-29 14:17:51.035418
# uuid             000b6bf7-4092-4eb6-b0f2-ddcfbafd29b5
# price                                         69580.0
# size                                         0.000734
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5583
# time_exchange              2024-03-29 14:17:58.201360
# time_coinapi               2024-03-29 14:17:58.228797
# uuid             08c475b4-c6a7-49dd-983f-088d68574c05
# price                                         69497.0
# size                                            0.111
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25197
# time_exchange              2024-03-29 14:18:06.636863
# time_coinapi               2024-03-29 14:18:06.658114
# uuid             851b0e0c-f436-40fc-8701-e8a621fec768
# price                                         69580.0
# size                                          0.00137
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10726
# time_exchange              2024-03-29 14:18:07.516000
# time_coinapi               2024-03-29 14:18:07.532222
# uuid             41bb8dcb-a2b5-4724-9f2a-def4c457ca9d
# price                                         69500.0
# size                                         0.000216
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25199
# time_exchange              2024-03-29 14:18:10.026467
# time_coinapi               2024-03-29 14:18:10.046193
# uuid             c3afe02e-0cb4-4126-aaea-d551497e5184
# price                                         69580.1
# size                                          0.00149
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10728
# time_exchange              2024-03-29 14:18:10.391000
# time_coinapi               2024-03-29 14:18:10.407120
# uuid             99bef732-757d-41ee-80a2-04cc1e3ce16e
# price                                         69501.0
# size                                         0.002346
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5585
# time_exchange              2024-03-29 14:18:16.607645
# time_coinapi               2024-03-29 14:18:16.635455
# uuid             f8bd0f88-ec1e-4cea-a561-e1416bcd2ef8
# price                                         69498.7
# size                                            0.111
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25201
# time_exchange              2024-03-29 14:18:19.943116
# time_coinapi               2024-03-29 14:18:19.964306
# uuid             32c0b307-4637-44c9-8b12-b2930b1b62f0
# price                                         69580.0
# size                                         0.007824
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43320
# time_exchange              2024-03-29 14:18:24.964000
# time_coinapi               2024-03-29 14:18:24.983052
# uuid             5ce01fa4-d973-45e3-9d56-cc39b6372077
# price                                         69509.0
# size                                            0.011
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43322
# time_exchange              2024-03-29 14:18:24.966000
# time_coinapi               2024-03-29 14:18:24.983117
# uuid             0a8a2eee-0a14-4cff-81ed-91ccbd604fd4
# price                                         69509.0
# size                                            0.011
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43324
# time_exchange              2024-03-29 14:18:24.967000
# time_coinapi               2024-03-29 14:18:24.992044
# uuid             fb441294-df7e-4eda-91cf-0db8e81a9504
# price                                         69509.0
# size                                            0.003
# taker_side                                       SELL
# Name: 4, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25203
# time_exchange              2024-03-29 14:18:28.663100
# time_coinapi               2024-03-29 14:18:28.683014
# uuid             9777072a-92ba-4762-bf5f-5f505a902ee1
# price                                         69580.0
# size                                         0.000478
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18265
# time_exchange              2024-03-29 14:18:31.920000
# time_coinapi               2024-03-29 14:18:31.946020
# uuid             b2bd1888-69a2-4083-8c81-29dd7c62f59c
# price                                         69540.0
# size                                          0.00043
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18267
# time_exchange              2024-03-29 14:18:34.278000
# time_coinapi               2024-03-29 14:18:34.342396
# uuid             5e9680a6-9ae5-4d2e-a2f4-80e79d0e0ab6
# price                                         69541.0
# size                                          0.00062
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25205
# time_exchange              2024-03-29 14:18:34.756463
# time_coinapi               2024-03-29 14:18:34.778072
# uuid             3a811fa5-6160-47fe-a7de-82411ce010ba
# price                                         69580.0
# size                                         0.004468
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18269
# time_exchange              2024-03-29 14:18:35.174000
# time_coinapi               2024-03-29 14:18:35.203134
# uuid             7f03c4ea-c933-41da-b7b5-be15b4bfc22c
# price                                         69540.0
# size                                         0.005084
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5587
# time_exchange              2024-03-29 14:18:35.238437
# time_coinapi               2024-03-29 14:18:35.265976
# uuid             83487430-8b61-4dd0-a716-4704b68a13b1
# price                                         69498.7
# size                                            0.111
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18271
# time_exchange              2024-03-29 14:18:37.965000
# time_coinapi               2024-03-29 14:18:37.996160
# uuid             5ab12965-f0ff-45fb-8d10-682e7a72c1c0
# price                                         69541.0
# size                                          0.00656
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18273
# time_exchange              2024-03-29 14:18:37.994000
# time_coinapi               2024-03-29 14:18:38.019504
# uuid             4df4ebca-6084-4e0b-854c-292dc4df70f8
# price                                         69541.0
# size                                          0.00782
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18275
# time_exchange              2024-03-29 14:18:37.994000
# time_coinapi               2024-03-29 14:18:38.035027
# uuid             0366631e-fff9-4c73-bf44-e6c048c665f4
# price                                         69543.0
# size                                          0.00204
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18277
# time_exchange              2024-03-29 14:18:42.190000
# time_coinapi               2024-03-29 14:18:42.215801
# uuid             da539363-fff6-41b2-86aa-8b6683c3bdef
# price                                         69546.0
# size                                          0.00138
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18279
# time_exchange              2024-03-29 14:18:45.646000
# time_coinapi               2024-03-29 14:18:45.682883
# uuid             b1529238-add2-426d-87f1-570bcef73187
# price                                         69561.0
# size                                          0.00206
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18281
# time_exchange              2024-03-29 14:18:49.074000
# time_coinapi               2024-03-29 14:18:49.103630
# uuid             9855fb91-fbf0-4826-97ee-3a56c763e9f6
# price                                         69558.0
# size                                         0.000699
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10730
# time_exchange              2024-03-29 14:18:50.112000
# time_coinapi               2024-03-29 14:18:50.153229
# uuid             2061bbe1-afd0-4b97-a256-9ce96af29a38
# price                                         69501.0
# size                                           0.0002
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25207
# time_exchange              2024-03-29 14:18:52.141285
# time_coinapi               2024-03-29 14:18:52.166103
# uuid             0cb552bd-0cf7-47f0-8d96-40b9dbcf889f
# price                                         69580.0
# size                                         0.000791
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25209
# time_exchange              2024-03-29 14:18:52.758919
# time_coinapi               2024-03-29 14:18:52.778969
# uuid             9a228bd0-665a-4bc3-a0e6-21cd657b9414
# price                                         69580.0
# size                                         0.000128
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25211
# time_exchange              2024-03-29 14:18:52.868824
# time_coinapi               2024-03-29 14:18:52.888651
# uuid             95de03e9-aad4-484a-ad33-90f56f004192
# price                                         69580.1
# size                                         0.180942
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18283
# time_exchange              2024-03-29 14:18:58.468000
# time_coinapi               2024-03-29 14:18:58.499358
# uuid             f151911a-e771-4aee-a3a8-603fe564f0d4
# price                                         69552.0
# size                                         0.000167
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25213
# time_exchange              2024-03-29 14:19:00.316796
# time_coinapi               2024-03-29 14:19:00.338117
# uuid             2be6ac54-7e68-406a-b0d6-173908cebfbf
# price                                         69580.0
# size                                         0.000107
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25215
# time_exchange              2024-03-29 14:19:01.180309
# time_coinapi               2024-03-29 14:19:01.255625
# uuid             ada69722-f1c2-44d4-8d14-5018c75d8c5a
# price                                         69580.0
# size                                         0.000363
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10732
# time_exchange              2024-03-29 14:19:01.784000
# time_coinapi               2024-03-29 14:19:01.800843
# uuid             757bd2e3-64b0-4348-acda-4397deaf4f0c
# price                                         69500.0
# size                                           0.0004
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25217
# time_exchange              2024-03-29 14:19:02.805880
# time_coinapi               2024-03-29 14:19:02.825958
# uuid             7e9ba46d-d1c3-4416-9556-5ae5e5f6a840
# price                                         69580.0
# size                                         0.000718
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18285
# time_exchange              2024-03-29 14:19:03.592000
# time_coinapi               2024-03-29 14:19:03.622055
# uuid             84236317-8f72-4fb9-bddc-ed7d14adf4cc
# price                                         69543.0
# size                                         0.000139
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5589
# time_exchange              2024-03-29 14:19:06.860951
# time_coinapi               2024-03-29 14:19:06.888429
# uuid             3cce099a-970f-4d12-8e17-0f423b32fdea
# price                                         69495.1
# size                                            0.111
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25219
# time_exchange              2024-03-29 14:19:08.393218
# time_coinapi               2024-03-29 14:19:08.413893
# uuid             437bbd72-f7c2-4f80-8c26-a0440b1d8f32
# price                                         69580.0
# size                                         0.359256
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25221
# time_exchange              2024-03-29 14:19:09.372354
# time_coinapi               2024-03-29 14:19:09.392219
# uuid             2e1dd3d2-3cd8-4cde-8c70-768b8c34e956
# price                                         69580.1
# size                                          0.00081
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25223
# time_exchange              2024-03-29 14:19:10.290066
# time_coinapi               2024-03-29 14:19:10.311350
# uuid             1ae51d1b-0983-4bb3-8296-eeae99e6dd09
# price                                         69580.1
# size                                         0.000266
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18287
# time_exchange              2024-03-29 14:19:11.874000
# time_coinapi               2024-03-29 14:19:11.909485
# uuid             48d8668d-ce61-40c8-9861-70231a0d3192
# price                                         69533.0
# size                                         0.002495
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25225
# time_exchange              2024-03-29 14:19:12.860436
# time_coinapi               2024-03-29 14:19:12.880620
# uuid             56288bbc-a3c5-420c-b556-b75f0cdffc17
# price                                         69580.0
# size                                             0.05
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25227
# time_exchange              2024-03-29 14:19:14.016562
# time_coinapi               2024-03-29 14:19:14.036489
# uuid             786e568b-90f4-4ebb-8766-37751b462c77
# price                                         69580.0
# size                                             0.05
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18289
# time_exchange              2024-03-29 14:19:16.891000
# time_coinapi               2024-03-29 14:19:16.920495
# uuid             c919d962-f291-4468-8e5f-f27a96929439
# price                                         69521.0
# size                                          0.00687
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10734
# time_exchange              2024-03-29 14:19:19.211000
# time_coinapi               2024-03-29 14:19:19.229771
# uuid             e594cd9f-deb0-4753-bb08-032ef61859d7
# price                                         69500.0
# size                                         0.131324
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10736
# time_exchange              2024-03-29 14:19:19.222000
# time_coinapi               2024-03-29 14:19:19.238928
# uuid             a22593c9-1a6e-49ec-9f9e-9b96f9d7392a
# price                                         69500.0
# size                                         0.131324
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10738
# time_exchange              2024-03-29 14:19:19.241000
# time_coinapi               2024-03-29 14:19:19.258149
# uuid             fd9efb83-e5b0-4dee-b0bd-e00e3a9a2e0c
# price                                         69500.0
# size                                         0.131324
# taker_side                                       SELL
# Name: 4, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10740
# time_exchange              2024-03-29 14:19:19.244000
# time_coinapi               2024-03-29 14:19:19.260876
# uuid             a108f38d-82e1-4fab-a79b-80cb7d966e3a
# price                                         69500.0
# size                                         0.492734
# taker_side                                       SELL
# Name: 1, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10742
# time_exchange              2024-03-29 14:19:19.268000
# time_coinapi               2024-03-29 14:19:19.298698
# uuid             db554155-2227-4b0b-b91a-454a10b9ff4f
# price                                         69500.0
# size                                         0.112678
# taker_side                                       SELL
# Name: 3, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10744
# time_exchange              2024-03-29 14:19:19.269000
# time_coinapi               2024-03-29 14:19:19.298999
# uuid             18b2bd99-61d8-42bd-9391-22fd40b8c62a
# price                                         69496.0
# size                                         0.009205
# taker_side                                       SELL
# Name: 5, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10746
# time_exchange              2024-03-29 14:19:19.270000
# time_coinapi               2024-03-29 14:19:19.299226
# uuid             860b73cd-ca48-42fe-ae92-b3dbe51f144a
# price                                         69496.0
# size                                            0.001
# taker_side                                       SELL
# Name: 7, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43326
# time_exchange              2024-03-29 14:19:19.345000
# time_coinapi               2024-03-29 14:19:19.368946
# uuid             bffc5c2b-a057-4383-a57e-08931b2d7835
# price                                         69508.0
# size                                         0.000044
# taker_side                                       SELL
# Name: 9, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43328
# time_exchange              2024-03-29 14:19:19.345000
# time_coinapi               2024-03-29 14:19:19.369118
# uuid             1c376bc2-f28a-4ab7-a2fa-d5b182632adb
# price                                         69508.0
# size                                         0.015975
# taker_side                                       SELL
# Name: 11, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43330
# time_exchange              2024-03-29 14:19:19.373000
# time_coinapi               2024-03-29 14:19:19.393226
# uuid             3a496dd9-973c-4ae8-8a28-d2bedc505d6a
# price                                         69508.0
# size                                         0.006025
# taker_side                                       SELL
# Name: 13, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10750
# time_exchange              2024-03-29 14:19:19.548000
# time_coinapi               2024-03-29 14:19:19.564964
# uuid             091475fe-fe82-4cf7-9417-d8c57838f607
# price                                         69494.0
# size                                            0.001
# taker_side                                       SELL
# Name: 17, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25229
# time_exchange              2024-03-29 14:19:20.032356
# time_coinapi               2024-03-29 14:19:20.069251
# uuid             01c1fd8d-e4f8-4657-af82-96dfd5d122f3
# price                                         69580.0
# size                                         0.000639
# taker_side                                       SELL
# Name: 19, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25231
# time_exchange              2024-03-29 14:19:20.207674
# time_coinapi               2024-03-29 14:19:20.232332
# uuid             c394010d-0ba3-4389-86c3-9a7115ceda6d
# price                                         69580.1
# size                                         0.000939
# taker_side                                        BUY
# Name: 21, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25233
# time_exchange              2024-03-29 14:19:20.337837
# time_coinapi               2024-03-29 14:19:20.357665
# uuid             b400c2d3-8007-4a36-abc4-3b32960f22aa
# price                                         69580.0
# size                                             0.02
# taker_side                                       SELL
# Name: 23, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25235
# time_exchange              2024-03-29 14:19:21.536010
# time_coinapi               2024-03-29 14:19:21.564802
# uuid             546c700a-916b-44cf-b00e-f3273e054c1d
# price                                         69580.0
# size                                             0.02
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5591
# time_exchange              2024-03-29 14:19:21.862359
# time_coinapi               2024-03-29 14:19:21.889712
# uuid             374566af-0b11-4892-8b28-829e447340a4
# price                                         69464.5
# size                                         0.003943
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5593
# time_exchange              2024-03-29 14:19:25.327693
# time_coinapi               2024-03-29 14:19:25.354622
# uuid             9b2f2b3e-2584-4ec0-be5f-3094e8b88ba5
# price                                         69470.8
# size                                            0.111
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10752
# time_exchange              2024-03-29 14:19:26.975000
# time_coinapi               2024-03-29 14:19:26.994239
# uuid             55962395-a80f-4498-bdb3-1594de15b131
# price                                         69494.0
# size                                              0.0
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10754
# time_exchange              2024-03-29 14:19:26.976000
# time_coinapi               2024-03-29 14:19:26.994868
# uuid             e575054c-7ba4-4f47-a741-8fd87a3d5c21
# price                                         69485.0
# size                                         0.000134
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18291
# time_exchange              2024-03-29 14:19:30.017000
# time_coinapi               2024-03-29 14:19:30.062427
# uuid             e8b34afe-1109-456f-8c94-1e9922b2e2b2
# price                                         69523.0
# size                                         0.001762
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18293
# time_exchange              2024-03-29 14:19:30.043000
# time_coinapi               2024-03-29 14:19:30.070045
# uuid             a8d575d6-f100-45a3-ba0d-c0f66bfb18f6
# price                                         69531.0
# size                                          0.00275
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18295
# time_exchange              2024-03-29 14:19:33.277000
# time_coinapi               2024-03-29 14:19:33.305709
# uuid             18433093-8180-4970-a5b8-11d4239670ea
# price                                         69531.0
# size                                         0.014382
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18297
# time_exchange              2024-03-29 14:19:33.277000
# time_coinapi               2024-03-29 14:19:33.320582
# uuid             8a368433-cb80-4c3b-b44e-662495434956
# price                                         69533.0
# size                                          0.43145
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18299
# time_exchange              2024-03-29 14:19:33.277000
# time_coinapi               2024-03-29 14:19:33.323717
# uuid             0a9f12b2-31c8-425c-b286-e2e0cfddb929
# price                                         69535.0
# size                                         0.014235
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18301
# time_exchange              2024-03-29 14:19:33.277000
# time_coinapi               2024-03-29 14:19:33.324190
# uuid             23a927a7-8c15-4394-9708-3d94647c4bb8
# price                                         69536.0
# size                                          0.04639
# taker_side                                        BUY
# Name: 4, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5595
# time_exchange              2024-03-29 14:19:39.154216
# time_coinapi               2024-03-29 14:19:39.180487
# uuid             96564601-cd43-4362-8e29-c81b3d32afc2
# price                                         69491.2
# size                                            0.022
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5597
# time_exchange              2024-03-29 14:19:39.154216
# time_coinapi               2024-03-29 14:19:39.180487
# uuid             e58ee0d4-5f72-4aa4-aee1-c42f9ff48a46
# price                                         69491.1
# size                                          0.15887
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18303
# time_exchange              2024-03-29 14:19:40.133000
# time_coinapi               2024-03-29 14:19:40.160066
# uuid             4a6215f8-2546-4ffe-a43c-35ff559a2346
# price                                         69541.0
# size                                          0.00287
# taker_side                                        BUY
# Name: 0, dtype: object
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
# RuntimeError: reentrant call inside <_io.BufferedReader name=80>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/context.py", line 381, in signal_handler
#     self.cancelAllJobs()
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/context.py", line 2446, in cancelAllJobs
#     self._jsc.sc().cancelAllJobs()
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py", line 179, in deco
#     return f(*a, **kw)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o19.sc
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In[1], line 105
#     102 query = value_df.writeStream.foreachBatch(process_batch).start()
#     104 # Wait for the stream to finish
# --> 105 query.awaitTermination()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/sql/streaming/query.py:221, in StreamingQuery.awaitTermination(self, timeout)
#     219     return self._jsq.awaitTermination(int(timeout * 1000))
#     220 else:
# --> 221     return self._jsq.awaitTermination()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o51.awaitTermination
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10756
# time_exchange              2024-03-29 14:19:41.687000
# time_coinapi               2024-03-29 14:19:41.704322
# uuid             dfbeffc4-766c-41fa-a57f-7f339a3b473c
# price                                         69485.0
# size                                         0.000866
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        10758
# time_exchange              2024-03-29 14:19:41.687000
# time_coinapi               2024-03-29 14:19:41.707740
# uuid             da8af468-9617-4a3e-b469-ddde6d74fd4b
# price                                         69485.0
# size                                         0.001602
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5599
# time_exchange              2024-03-29 14:19:43.717206
# time_coinapi               2024-03-29 14:19:43.743405
# uuid             1424b64d-a1b7-478d-8817-60f253d525ee
# price                                         69487.4
# size                                            0.111
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43332
# time_exchange              2024-03-29 14:19:47.568000
# time_coinapi               2024-03-29 14:19:47.586014
# uuid             b0a7fd94-323a-440c-a0e7-97a3ab9f3896
# price                                         69506.0
# size                                         0.000044
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        43334
# time_exchange              2024-03-29 14:19:47.568000
# time_coinapi               2024-03-29 14:19:47.594441
# uuid             7835c3d9-5f97-46cc-a069-7d992bc98db3
# price                                         69506.0
# size                                            0.002
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18307
# time_exchange              2024-03-29 14:19:59.795000
# time_coinapi               2024-03-29 14:19:59.822993
# uuid             9981fe78-b249-4fc8-aa12-0f15a671f62f
# price                                         69542.0
# size                                          0.00206
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25237
# time_exchange              2024-03-29 14:20:01.109158
# time_coinapi               2024-03-29 14:20:01.128921
# uuid             e29711ef-3e0f-40c2-8cb3-c8bf96b79da7
# price                                         69580.1
# size                                         0.000517
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5601
# time_exchange              2024-03-29 14:20:02.106255
# time_coinapi               2024-03-29 14:20:02.155873
# uuid             59b1851f-2c7d-48d1-8edf-d13039675c7e
# price                                         69498.2
# size                                             0.05
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5603
# time_exchange              2024-03-29 14:20:02.106255
# time_coinapi               2024-03-29 14:20:02.155873
# uuid             2336e5e9-7761-41cc-9265-9134490b2ef3
# price                                         69501.1
# size                                         0.000549
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDC
# sequence                                         1513
# time_exchange              2024-03-29 14:20:05.165051
# time_coinapi               2024-03-29 14:20:05.191093
# uuid             b6842a0c-556c-40d3-9779-6ace768f1f12
# price                                        69540.37
# size                                         0.000908
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5605
# time_exchange              2024-03-29 14:20:05.447920
# time_coinapi               2024-03-29 14:20:05.480019
# uuid             7475788d-b5b4-4542-aabb-b96df54cf0fc
# price                                         69497.1
# size                                             0.05
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5607
# time_exchange              2024-03-29 14:20:05.447920
# time_coinapi               2024-03-29 14:20:05.480019
# uuid             9073d68d-39aa-42dc-9ab3-9faacdbc5243
# price                                         69497.2
# size                                             0.01
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25239
# time_exchange              2024-03-29 14:20:06.313734
# time_coinapi               2024-03-29 14:20:06.333795
# uuid             da1c9519-e50b-4f10-9c24-c2b330d21300
# price                                         69580.1
# size                                         0.005007
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25241
# time_exchange              2024-03-29 14:20:08.031976
# time_coinapi               2024-03-29 14:20:08.052644
# uuid             e577802e-3dcf-461b-ac43-de2e08a14876
# price                                         69580.0
# size                                         0.001332
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                      BITSTAMP_SPOT_BTC_USDC
# sequence                                          394
# time_exchange              2024-03-29 14:20:10.893000
# time_coinapi               2024-03-29 14:20:10.924028
# uuid             a00deff0-c3e7-4846-b27c-9278b4878946
# price                                         69531.0
# size                                         0.002884
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18309
# time_exchange              2024-03-29 14:20:11.125000
# time_coinapi               2024-03-29 14:20:11.155059
# uuid             14012b31-4535-4044-a620-ff2f46b77e74
# price                                         69543.0
# size                                         0.002783
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18311
# time_exchange              2024-03-29 14:20:11.909000
# time_coinapi               2024-03-29 14:20:11.937148
# uuid             8d498230-91fd-4acd-922e-7291562da0b8
# price                                         69528.0
# size                                         0.014383
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25243
# time_exchange              2024-03-29 14:20:13.066246
# time_coinapi               2024-03-29 14:20:13.092479
# uuid             a2978c98-bddf-4e4b-9c52-f54410b47689
# price                                         69580.0
# size                                             0.05
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25245
# time_exchange              2024-03-29 14:20:13.142229
# time_coinapi               2024-03-29 14:20:13.165720
# uuid             01c18094-a425-4213-99e1-371df9620dbd
# price                                         69580.0
# size                                         0.005582
# taker_side                                       SELL
# Name: 2, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25247
# time_exchange              2024-03-29 14:20:14.577647
# time_coinapi               2024-03-29 14:20:14.598239
# uuid             f54e7389-c7c4-4468-ba11-1ee483fc351e
# price                                         69580.0
# size                                         0.000299
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25249
# time_exchange              2024-03-29 14:20:15.365273
# time_coinapi               2024-03-29 14:20:15.385274
# uuid             6d0f009b-4d0c-44ef-8ab5-72788c05339d
# price                                         69580.0
# size                                         0.000508
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18313
# time_exchange              2024-03-29 14:20:13.021000
# time_coinapi               2024-03-29 14:20:13.060133
# uuid             db154cf8-4fd5-4c56-b903-7aac7aa6b529
# price                                         69530.0
# size                                          0.00678
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18315
# time_exchange              2024-03-29 14:20:13.581000
# time_coinapi               2024-03-29 14:20:13.605541
# uuid             8c7b16c8-63c5-435a-8ff8-8b14538345f5
# price                                         69530.0
# size                                          0.00208
# taker_side                                        BUY
# Name: 2, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25251
# time_exchange              2024-03-29 14:20:16.794395
# time_coinapi               2024-03-29 14:20:16.814678
# uuid             0df38dda-69c4-4204-95aa-5fd8f4cd6e87
# price                                         69580.0
# size                                         0.000299
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5609
# time_exchange              2024-03-29 14:20:20.623687
# time_coinapi               2024-03-29 14:20:20.654415
# uuid             c59f0490-dcb2-4b63-a52e-4b6dba1af100
# price                                         69483.0
# size                                            0.111
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25253
# time_exchange              2024-03-29 14:20:20.911142
# time_coinapi               2024-03-29 14:20:20.940658
# uuid             e3b6f3df-8990-48c2-bca9-b7a57d8918b9
# price                                         69580.1
# size                                         0.003156
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18317
# time_exchange              2024-03-29 14:20:24.947000
# time_coinapi               2024-03-29 14:20:24.972914
# uuid             3e1045ee-01c7-48f1-9308-e3f233f0fbae
# price                                         69530.0
# size                                          0.00037
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25255
# time_exchange              2024-03-29 14:20:26.038232
# time_coinapi               2024-03-29 14:20:26.061160
# uuid             83071c6d-c625-4459-b601-c3edaa2cfaa9
# price                                         69580.0
# size                                             0.05
# taker_side                                       SELL
# Name: 0, dtype: object
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        25257
# time_exchange              2024-03-29 14:20:26.773799
# time_coinapi               2024-03-29 14:20:26.793887
# uuid             3b7bf644-af61-4daf-833a-9dea091b22fb
# price                                         69580.1
# size                                         0.001346
# taker_side                                        BUY
# Name: 0, dtype: object
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18319
# time_exchange              2024-03-29 14:20:27.371000
# time_coinapi               2024-03-29 14:20:27.400017
# uuid             19eaf5ae-b7a1-48f7-a0b1-f7b05031ff76
# price                                         69530.0
# size                                         0.000139
# taker_side                                        BUY
# Name: 0, dtype: object

# %%
query.stop()

# %%
spark.stop()
