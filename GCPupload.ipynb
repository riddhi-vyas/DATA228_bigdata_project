# %%
import numpy as np
import hashlib
from pyspark.sql.functions import col, from_json
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from scipy.stats import laplace  # Import Laplace distribution for differential privacy
import os
from google.cloud import storage

# Define SimpleFilter class
class SimpleFilter:
    def __init__(self, size, hash_count):
        self.size = size
        self.hash_count = hash_count
        self.bit_array = np.zeros(size, dtype=np.bool_)

    def _hash(self, item, seed):
        hash_val = int(hashlib.md5(item.encode('utf-8')).hexdigest(), 16)
        return (hash_val + seed) % self.size

    def add(self, item):
        for seed in range(self.hash_count):
            index = self._hash(item, seed)
            self.bit_array[index] = True

    def check(self, item):
        for seed in range(self.hash_count):
            index = self._hash(item, seed)
            if not self.bit_array[index]:
                return False
        return True

# Initialize Spark session
spark = SparkSession \
    .builder \
    .appName("StreamingWithBloomFilter") \
    .master("local[*]") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.1") \
    .getOrCreate()

# Define the schema of the message
messageSchema = StructType([
    StructField("symbol_id", StringType()),
    StructField("sequence", StringType()),
    StructField("time_exchange", TimestampType()),
    StructField("time_coinapi", TimestampType()),
    StructField("uuid", StringType()),
    StructField("price", DoubleType()),
    StructField("size", DoubleType()),
    StructField("taker_side", StringType())
])

# Subscribe to multiple topics
topic_names = "bitstamp_btc_usd,bitfinex_btc_usd,kraken_btc_usd"

# Create a streaming DataFrame that reads from the topics
df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", topic_names) \
    .load()

# Deserialize the JSON data and apply the schema
value_df = df.select(from_json(col("value").cast("string"), messageSchema).alias("data")).select("data.*")

# Initialize the Bloom Filter
bloom_filter = SimpleFilter(10000, 3)

# Define the local folder path
local_folder_path = "/Users/priyasuresh/googlecloud"

# Define the Google Cloud Storage bucket name
bucket_name = "bigdataproject_cryptocurrency"

# Function to add Laplacian noise for differential privacy
def add_laplace_noise(data, epsilon=1.0, sensitivity=1):
    try:
        # Convert data to float and then add Laplace noise
        data_float = float(data)
        scale = sensitivity / epsilon
        noise = laplace.rvs(scale=scale, size=1)[0]
        return str(data_float + noise)  # Convert back to string after adding noise
    except ValueError:
        # If data cannot be converted to float (e.g., UUID), return the original value
        return data

# Define process_batch function with differential privacy, local saving, and GCS uploading
def process_batch(batch_df, batch_id):
    # Convert to Pandas DataFrame for easier manipulation
    pandas_df = batch_df.toPandas()
    
    # Apply differential privacy to each UUID
    pandas_df['uuid'] = pandas_df['uuid'].apply(add_laplace_noise)
    
    # Apply the Bloom Filter to each row
    for index, row in pandas_df.iterrows():
        uuid = row['uuid']
        if not bloom_filter.check(uuid):
            bloom_filter.add(uuid)  # Use add method to insert UUID into the Bloom filter
            # Process the row since it's not a duplicate
            print(row)
            # Save the row to a CSV file locally
            file_path = os.path.join(local_folder_path, f"batch_{batch_id}_{index}.csv")
            row.to_csv(file_path, index=False)
            print(f"Row saved to: {file_path}")
            # Upload the file to Google Cloud Storage
            upload_to_gcs(file_path)
            # Delete the local file after uploading
            os.remove(file_path)

# Function to upload file to Google Cloud Storage
def upload_to_gcs(file_path):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    destination_blob_name = os.path.basename(file_path)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(file_path)
    print(f"File uploaded to GCS: gs://{bucket_name}/{destination_blob_name}")

# Apply the function to each micro-batch
query = value_df.writeStream.foreachBatch(process_batch).start()

# Wait for the stream to finish
query.awaitTermination()
# Out:
# 24/03/29 14:48:58 WARN Utils: Your hostname, Priyas-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.68.59 instead (on interface en0)
# 24/03/29 14:48:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/priyasuresh/.ivy2/cache
# The jars for the packages stored in: /Users/priyasuresh/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-e936e6a3-eeff-4b5d-bb5d-4857ec7ae283;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.1 in central
# 	found org.apache.kafka#kafka-clients;3.4.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.3 in central
# 	found org.slf4j#slf4j-api;2.0.7 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# :: resolution report :: resolve 198ms :: artifacts dl 5ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.7 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-e936e6a3-eeff-4b5d-bb5d-4857ec7ae283
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/4ms)
# 24/03/29 14:48:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/29 14:48:59 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/29 14:49:00 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/9j/0m5g2l6d03z4pd5y6pt7xh1h0000gn/T/temporary-f561d8b8-8710-4232-9b12-04273ec03a21. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/03/29 14:49:00 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/03/29 14:49:01 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        11111
# time_exchange              2024-03-29 14:49:01.380000
# time_coinapi               2024-03-29 14:49:01.399862
# uuid             1cf365cd-3649-443e-b426-798a7dffb99d
# price                                         69453.0
# size                                           0.0004
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_1_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_1_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44123
# time_exchange              2024-03-29 14:49:04.711000
# time_coinapi               2024-03-29 14:49:04.729673
# uuid             a79b0eb9-fff2-476e-aaa8-64cf9dace6aa
# price                                         69464.0
# size                                            0.003
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_2_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_2_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44125
# time_exchange              2024-03-29 14:49:04.711000
# time_coinapi               2024-03-29 14:49:04.729741
# uuid             6a2cc531-894e-4cb4-a1ab-3b93919d5cf2
# price                                         69464.0
# size                                         0.000821
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_2_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_2_2.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18948
# time_exchange              2024-03-29 14:49:09.852000
# time_coinapi               2024-03-29 14:49:09.882218
# uuid             80733eb5-bee7-4faa-80e1-2ff8890db7aa
# price                                         69496.0
# size                                         0.000222
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_3_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_3_0.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18950
# time_exchange              2024-03-29 14:49:11.075000
# time_coinapi               2024-03-29 14:49:11.102870
# uuid             4bc4f19e-6ce8-4835-b1c9-61a2e68f9858
# price                                         69496.0
# size                                          0.00251
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_4_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_4_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26435
# time_exchange              2024-03-29 14:49:15.610754
# time_coinapi               2024-03-29 14:49:15.632702
# uuid             20c47512-24ec-47da-ad81-0958c5bb16e2
# price                                         69496.6
# size                                           0.0009
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_5_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_5_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26437
# time_exchange              2024-03-29 14:49:15.610754
# time_coinapi               2024-03-29 14:49:15.632702
# uuid             19bbb3e9-e583-40b1-82e1-fa55b8e98918
# price                                         69496.6
# size                                          0.00261
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_5_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_5_2.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44127
# time_exchange              2024-03-29 14:49:18.844000
# time_coinapi               2024-03-29 14:49:18.861967
# uuid             ab6d3042-d828-40bd-aaa8-ab4a740ec241
# price                                         69463.0
# size                                            0.018
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44129
# time_exchange              2024-03-29 14:49:18.844000
# time_coinapi               2024-03-29 14:49:18.862058
# uuid             ff22cfe6-df65-4c74-88f7-1de9982d4a72
# price                                         69463.0
# size                                            0.015
# taker_side                                       SELL
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_2.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44131
# time_exchange              2024-03-29 14:49:18.845000
# time_coinapi               2024-03-29 14:49:18.862093
# uuid             3fe1dccd-df4d-4bef-a908-649445b91f19
# price                                         69463.0
# size                                         0.086596
# taker_side                                       SELL
# Name: 4, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_4.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_4.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44133
# time_exchange              2024-03-29 14:49:18.845000
# time_coinapi               2024-03-29 14:49:18.862121
# uuid             0d9199f5-24a5-4d11-bac2-550979adbf2a
# price                                         69463.0
# size                                         0.107574
# taker_side                                       SELL
# Name: 6, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_6.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_6.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44135
# time_exchange              2024-03-29 14:49:18.845000
# time_coinapi               2024-03-29 14:49:18.867096
# uuid             e49fbf8b-8501-4c50-9d7c-1e60a94e3294
# price                                         69459.0
# size                                         0.010577
# taker_side                                       SELL
# Name: 8, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_8.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_8.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18952
# time_exchange              2024-03-29 14:49:18.700000
# time_coinapi               2024-03-29 14:49:18.728388
# uuid             ad3f371d-1a05-423c-8ce1-152ee8910502
# price                                         69496.0
# size                                          0.00522
# taker_side                                        BUY
# Name: 10, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_10.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_10.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26439
# time_exchange              2024-03-29 14:49:17.556677
# time_coinapi               2024-03-29 14:49:17.577906
# uuid             722fadb4-53d5-4820-8986-9606026f0c99
# price                                         69497.7
# size                                           0.0002
# taker_side                                        BUY
# Name: 12, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_6_12.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_6_12.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26441
# time_exchange              2024-03-29 14:49:25.023830
# time_coinapi               2024-03-29 14:49:25.044288
# uuid             a6f9b470-6a10-45be-8cb4-c2acc6209d7f
# price                                         69497.7
# size                                         0.001746
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_7_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_7_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26443
# time_exchange              2024-03-29 14:49:25.259712
# time_coinapi               2024-03-29 14:49:25.279804
# uuid             70126ca3-3d72-48d1-b6ea-88a7106aebbb
# price                                         69497.7
# size                                         0.000132
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_7_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_7_2.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26445
# time_exchange              2024-03-29 14:49:30.433219
# time_coinapi               2024-03-29 14:49:30.453229
# uuid             fbf7a1f7-9a6e-4c5f-9907-148cd6358775
# price                                         69497.6
# size                                         0.002745
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_8_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_8_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26447
# time_exchange              2024-03-29 14:49:41.860769
# time_coinapi               2024-03-29 14:49:41.883190
# uuid             ab08485f-d75c-4ed0-b714-c9f4d88f2a31
# price                                         69497.7
# size                                         0.002577
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_9_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_9_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26449
# time_exchange              2024-03-29 14:49:42.394228
# time_coinapi               2024-03-29 14:49:42.416237
# uuid             611ff414-167e-447d-aea2-554236ffed51
# price                                         69497.7
# size                                         0.001432
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_10_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_10_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26451
# time_exchange              2024-03-29 14:49:45.724234
# time_coinapi               2024-03-29 14:49:45.746411
# uuid             0bbcabf3-8d5e-4e13-abbc-664c135e1fa9
# price                                         69497.7
# size                                         0.002012
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_11_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_11_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44137
# time_exchange              2024-03-29 14:49:48.349000
# time_coinapi               2024-03-29 14:49:48.367428
# uuid             5658e484-54ae-4b27-8489-28041c73d578
# price                                         69464.0
# size                                            0.002
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_12_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_12_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44139
# time_exchange              2024-03-29 14:49:48.350000
# time_coinapi               2024-03-29 14:49:48.367537
# uuid             67686ed7-5a32-4d58-9544-7d9c5a259e7e
# price                                         69464.0
# size                                         0.001599
# taker_side                                       SELL
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_12_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_12_2.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18954
# time_exchange              2024-03-29 14:49:48.848000
# time_coinapi               2024-03-29 14:49:48.877533
# uuid             e732d7c7-76a3-4181-b6f5-deada3f30668
# price                                         69480.0
# size                                         0.001348
# taker_side                                       SELL
# Name: 1, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_13_1.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_13_1.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26453
# time_exchange              2024-03-29 14:49:49.399657
# time_coinapi               2024-03-29 14:49:49.422907
# uuid             645e6f4c-7fa6-4e1e-951f-dae5f2e932db
# price                                         69497.7
# size                                         0.004882
# taker_side                                        BUY
# Name: 3, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_13_3.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_13_3.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26455
# time_exchange              2024-03-29 14:49:51.713759
# time_coinapi               2024-03-29 14:49:51.735886
# uuid             50ceea0b-7a71-457b-a54b-40116d8da0d2
# price                                         69497.7
# size                                         0.002808
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_14_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_14_0.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18956
# time_exchange              2024-03-29 14:50:00.581000
# time_coinapi               2024-03-29 14:50:00.609916
# uuid             f35aa235-7302-4edc-8411-7d381969a3d0
# price                                         69492.0
# size                                         0.000836
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_15_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_15_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26457
# time_exchange              2024-03-29 14:50:01.163633
# time_coinapi               2024-03-29 14:50:01.189840
# uuid             ed380d68-2a0c-4c84-a921-8b916d141802
# price                                         69497.6
# size                                         0.000649
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_16_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_16_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26459
# time_exchange              2024-03-29 14:50:02.653207
# time_coinapi               2024-03-29 14:50:02.675825
# uuid             53fa093a-c7d6-4b27-9c77-d8ae7a4d087f
# price                                         69497.6
# size                                         0.000028
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_17_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_17_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26461
# time_exchange              2024-03-29 14:50:02.653207
# time_coinapi               2024-03-29 14:50:02.675825
# uuid             c7408959-7598-4527-acea-56132e603b79
# price                                         69497.6
# size                                         0.005582
# taker_side                                       SELL
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_17_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_17_2.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26463
# time_exchange              2024-03-29 14:50:02.653207
# time_coinapi               2024-03-29 14:50:02.675825
# uuid             778e2548-a641-4d71-a6cb-13d5f5f43b8f
# price                                         69497.6
# size                                            0.001
# taker_side                                       SELL
# Name: 4, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_17_4.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_17_4.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26465
# time_exchange              2024-03-29 14:50:02.653207
# time_coinapi               2024-03-29 14:50:02.675825
# uuid             893011f4-10a0-4c61-9622-4cfafd70230e
# price                                         69497.6
# size                                         0.001928
# taker_side                                       SELL
# Name: 6, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_17_6.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_17_6.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26467
# time_exchange              2024-03-29 14:50:02.653207
# time_coinapi               2024-03-29 14:50:02.675825
# uuid             d8727f93-56d1-43db-8c6e-8cba20b93d0a
# price                                         69497.1
# size                                         0.001376
# taker_side                                       SELL
# Name: 8, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_17_8.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_17_8.csv
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        11113
# time_exchange              2024-03-29 14:50:03.642000
# time_coinapi               2024-03-29 14:50:03.659306
# uuid             cb71fbbf-1a29-4088-9e44-0a984845a2f9
# price                                         69454.0
# size                                         0.000262
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_18_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_18_0.csv
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        11115
# time_exchange              2024-03-29 14:50:03.930000
# time_coinapi               2024-03-29 14:50:03.947884
# uuid             a8f92a3c-fb55-4901-8475-0d4e4feda990
# price                                         69460.0
# size                                         0.000148
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_18_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_18_2.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18958
# time_exchange              2024-03-29 14:50:05.808000
# time_coinapi               2024-03-29 14:50:05.839007
# uuid             7d92d7c1-4f32-41c2-bfa3-f41a550a3739
# price                                         69492.0
# size                                          0.00696
# taker_side                                        BUY
# Name: 4, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_18_4.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_18_4.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26469
# time_exchange              2024-03-29 14:50:06.892055
# time_coinapi               2024-03-29 14:50:06.915601
# uuid             146e49df-f0a0-4329-88fc-3b8e28aa336e
# price                                         69497.2
# size                                         0.000267
# taker_side                                        BUY
# Name: 6, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_18_6.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_18_6.csv
# symbol_id                        KRAKEN_SPOT_BTC_USDT
# sequence                                         5715
# time_exchange              2024-03-29 14:50:07.003837
# time_coinapi               2024-03-29 14:50:07.032133
# uuid             97089a61-d1bd-4bad-b38c-4b07698a6926
# price                                         69456.8
# size                                         0.014999
# taker_side                                       SELL
# Name: 8, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_18_8.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_18_8.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44141
# time_exchange              2024-03-29 14:50:13.786000
# time_coinapi               2024-03-29 14:50:13.804531
# uuid             7f3d3dba-507c-43ba-b0c3-ef5cc150f56f
# price                                         69465.0
# size                                         0.000044
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_19_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_19_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44143
# time_exchange              2024-03-29 14:50:13.786000
# time_coinapi               2024-03-29 14:50:13.804607
# uuid             8b47062a-cc5e-44f7-b5f9-34fc3731bfd8
# price                                         69465.0
# size                                            0.003
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_19_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_19_2.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44145
# time_exchange              2024-03-29 14:50:13.787000
# time_coinapi               2024-03-29 14:50:13.804647
# uuid             4dc473c8-c399-4431-bf00-ecd775213983
# price                                         69465.0
# size                                         0.000777
# taker_side                                        BUY
# Name: 4, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_19_4.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_19_4.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18960
# time_exchange              2024-03-29 14:50:15.386000
# time_coinapi               2024-03-29 14:50:15.413588
# uuid             7264bd34-463e-4568-bdfa-72c470de25d3
# price                                         69495.0
# size                                          0.00088
# taker_side                                        BUY
# Name: 6, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_19_6.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_19_6.csv
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        11117
# time_exchange              2024-03-29 14:50:16.445000
# time_coinapi               2024-03-29 14:50:16.470350
# uuid             96311a20-79df-4b56-834f-515eef54e7f0
# price                                         69460.0
# size                                         0.000363
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_20_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_20_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26471
# time_exchange              2024-03-29 14:50:18.007930
# time_coinapi               2024-03-29 14:50:18.033112
# uuid             d5dd8994-3750-464b-aaf5-d9eac3c6de31
# price                                         69497.1
# size                                           0.0001
# taker_side                                       SELL
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_20_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_20_2.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26473
# time_exchange              2024-03-29 14:50:18.007930
# time_coinapi               2024-03-29 14:50:18.033112
# uuid             874ff60a-34a0-4c5c-af10-53ed1ede0744
# price                                         69497.1
# size                                           0.0001
# taker_side                                       SELL
# Name: 4, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_20_4.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_20_4.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18962
# time_exchange              2024-03-29 14:50:29.382000
# time_coinapi               2024-03-29 14:50:29.409068
# uuid             f29a606d-8585-4925-8867-af7f224b4366
# price                                         69495.0
# size                                          0.00144
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_21_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_21_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26475
# time_exchange              2024-03-29 14:50:31.210618
# time_coinapi               2024-03-29 14:50:31.231054
# uuid             d3d77469-7aa4-4284-bb05-80d5a5dd09c9
# price                                         69497.2
# size                                         0.009719
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_22_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_22_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26477
# time_exchange              2024-03-29 14:50:32.842755
# time_coinapi               2024-03-29 14:50:32.863637
# uuid             0c31ee12-a2bb-404e-aed5-04d5e94dc670
# price                                         69497.1
# size                                          0.00121
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_23_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_23_0.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18964
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.920413
# uuid             429970ad-88df-448b-a4f5-41d0dcb74d21
# price                                         69487.0
# size                                         0.000866
# taker_side                                       SELL
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_24_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_24_0.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18966
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.945981
# uuid             226f82fe-c9bc-4115-a634-1910918977ff
# price                                         69486.0
# size                                         0.014391
# taker_side                                       SELL
# Name: 1, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_1.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_1.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18968
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.946148
# uuid             cc079753-24ee-46b4-bafb-33032c59ca57
# price                                         69484.0
# size                                         0.431752
# taker_side                                       SELL
# Name: 3, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_3.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_3.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18970
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.946188
# uuid             cfefae2d-29a3-4061-80dc-2c7ec055f526
# price                                         69481.0
# size                                         0.006512
# taker_side                                       SELL
# Name: 5, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_5.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_5.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18972
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.947088
# uuid             a27c0fa2-2061-49da-a07b-00eac3b70433
# price                                         69480.0
# size                                         0.172725
# taker_side                                       SELL
# Name: 7, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_7.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_7.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18974
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.953680
# uuid             7da461c3-7e12-4b0c-a27c-ee4614b8b081
# price                                         69479.0
# size                                             0.06
# taker_side                                       SELL
# Name: 9, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_9.csv
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
# RuntimeError: reentrant call inside <_io.BufferedReader name=80>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/context.py", line 381, in signal_handler
#     self.cancelAllJobs()
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/context.py", line 2446, in cancelAllJobs
#     self._jsc.sc().cancelAllJobs()
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py", line 179, in deco
#     return f(*a, **kw)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o19.sc
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Users/priyasuresh/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_9.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18976
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.953812
# uuid             30ea7fd5-99c3-4099-90a1-db87762859a9
# price                                         69479.0
# size                                         0.431782
# taker_side                                       SELL
# Name: 11, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_11.csv
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In[1], line 125
#     122 query = value_df.writeStream.foreachBatch(process_batch).start()
#     124 # Wait for the stream to finish
# --> 125 query.awaitTermination()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/sql/streaming/query.py:221, in StreamingQuery.awaitTermination(self, timeout)
#     219     return self._jsq.awaitTermination(int(timeout * 1000))
#     220 else:
# --> 221     return self._jsq.awaitTermination()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o51.awaitTermination
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_11.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18978
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.953865
# uuid             06ce6981-7f73-4833-9c4e-b0d38a1aad21
# price                                         69478.0
# size                                         0.006512
# taker_side                                       SELL
# Name: 13, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_13.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_13.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18980
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.953893
# uuid             9b9b847e-ff60-4ced-b6ad-8a9752954ab0
# price                                         69473.0
# size                                         1.101548
# taker_side                                       SELL
# Name: 15, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_15.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_15.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18982
# time_exchange              2024-03-29 14:50:34.893000
# time_coinapi               2024-03-29 14:50:34.953946
# uuid             7c212bc0-5a23-4c2f-baae-c13976d64358
# price                                         69471.0
# size                                         0.430968
# taker_side                                       SELL
# Name: 17, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_17.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_17.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18984
# time_exchange              2024-03-29 14:50:35.910000
# time_coinapi               2024-03-29 14:50:35.937020
# uuid             21f66f7a-9469-4a12-9d7e-b7fe81994350
# price                                         69500.0
# size                                         0.004184
# taker_side                                        BUY
# Name: 19, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_19.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_19.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26479
# time_exchange              2024-03-29 14:50:35.280026
# time_coinapi               2024-03-29 14:50:35.307466
# uuid             6dc226ac-9717-463b-af03-54be6f3fd344
# price                                         69497.7
# size                                         0.000211
# taker_side                                        BUY
# Name: 21, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_25_21.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_25_21.csv
# symbol_id                      BITFINEX_SPOT_BTC_USDT
# sequence                                        11119
# time_exchange              2024-03-29 14:50:39.302000
# time_coinapi               2024-03-29 14:50:39.321517
# uuid             767e9b94-2a0a-4a4b-b44a-f28e70eb313f
# price                                         69465.0
# size                                         0.000408
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_26_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_26_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26481
# time_exchange              2024-03-29 14:50:39.411051
# time_coinapi               2024-03-29 14:50:39.431549
# uuid             1c62bdf4-d43e-4b29-be61-1cf00c70f3c5
# price                                         69498.0
# size                                         0.000132
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_26_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_26_2.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44147
# time_exchange              2024-03-29 14:50:48.893000
# time_coinapi               2024-03-29 14:50:48.913156
# uuid             4ba6fcf8-a2d4-4466-a9e4-c11c8b5b08c8
# price                                         69467.0
# size                                         0.000044
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_27_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_27_0.csv
# symbol_id                       BITFINEX_SPOT_BTC_USD
# sequence                                        44149
# time_exchange              2024-03-29 14:50:48.894000
# time_coinapi               2024-03-29 14:50:48.913404
# uuid             8a52368c-0a83-4fc1-83c3-25da12499340
# price                                         69467.0
# size                                         0.001866
# taker_side                                        BUY
# Name: 2, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_27_2.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_27_2.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26483
# time_exchange              2024-03-29 14:50:50.490255
# time_coinapi               2024-03-29 14:50:50.510515
# uuid             f8477831-2c87-476b-96c6-decb70d55dbd
# price                                         69498.0
# size                                          0.00142
# taker_side                                        BUY
# Name: 4, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_27_4.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_27_4.csv
# symbol_id                       BITSTAMP_SPOT_BTC_USD
# sequence                                        18986
# time_exchange              2024-03-29 14:50:56.466000
# time_coinapi               2024-03-29 14:50:56.491984
# uuid             c3358f0d-5b8a-4147-83c6-23e395f1dd3d
# price                                         69504.0
# size                                          0.01316
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_28_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_28_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26485
# time_exchange              2024-03-29 14:51:01.605313
# time_coinapi               2024-03-29 14:51:01.625436
# uuid             8758b931-7898-4a64-84df-529cd4084f46
# price                                         69498.0
# size                                         0.000402
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_30_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_30_0.csv
# symbol_id                         KRAKEN_SPOT_BTC_USD
# sequence                                        26487
# time_exchange              2024-03-29 14:51:01.897355
# time_coinapi               2024-03-29 14:51:01.917608
# uuid             74895ba4-e1af-49f0-b09c-8061fafe71fe
# price                                         69498.0
# size                                         0.001402
# taker_side                                        BUY
# Name: 0, dtype: object
# Row saved to: /Users/priyasuresh/googlecloud/batch_31_0.csv
# File uploaded to GCS: gs://bigdataproject_cryptocurrency/batch_31_0.csv

# %%
query.stop()

# %%
spark.stop()
