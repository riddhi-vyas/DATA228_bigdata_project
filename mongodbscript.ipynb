# %%
# !pip install pymongo

# %%
# !pip install apscheduler
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import os
import time
import json
from pymongo import MongoClient
from apscheduler.schedulers.background import BackgroundScheduler

# MongoDB credentials and connection details
mongo_user = 'admin'  
mongo_pass = 'Welcome@123'  
mongo_host = 'localhost'
mongo_port = 27017  
mongo_db_name = 'bigdataproject'  
mongo_collection_name = 'trades'  

# Establish a connection to the MongoDB server
client = MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_pass,
    authSource='admin'  # The database that holds the user’s credentials
)

# Specify the database and collection
db = client[mongo_db_name]
collection = db[mongo_collection_name]

# Folder containing JSON files
folder_path = "/Users/priyasuresh/Documents/Documents_Priya’s MacBook Pro/SPRING2024/Data 228-Big Data/project/old_json"  # Update the path to the folder with JSON files

def load_json_files_to_mongodb():
    """Function to load JSON files into MongoDB and remove them."""
    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                try:
                    # Load each file as a JSON object and insert into MongoDB
                    data = json.load(file)
                    collection.insert_one(data)
                    print(f"Inserted {filename} into MongoDB")
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON from {filename}: {e}")
                    continue
                except Exception as e:
                    print(f"Error inserting {filename} into MongoDB: {e}")
                    continue

                # Remove the file after processing
                try:
                    os.remove(file_path)
                    print(f"Deleted {filename} after insertion")
                except Exception as e:
                    print(f"Error deleting {filename}: {e}")

def run_scheduler():
    """Function to start the scheduler."""
    scheduler = BackgroundScheduler()
    scheduler.add_job(load_json_files_to_mongodb, 'interval', minutes=5)
    scheduler.start()
    print("Scheduler started, Ctrl+C to exit.")

    # Keep the script running
    try:
        while True:
            time.sleep(2)
    except (KeyboardInterrupt, SystemExit):
        scheduler.shutdown()

if __name__ == "__main__":
    run_scheduler()
# Out:
# Scheduler started, Ctrl+C to exit.

# %%
import json
from pymongo import MongoClient

# MongoDB credentials and connection details
mongo_user = 'admin'  # Replace with your MongoDB admin username
mongo_pass = 'Welcome@123'  # Replace with your MongoDB admin password
mongo_host = 'localhost'
mongo_port = 27017  # Default MongoDB port
mongo_db_name = 'bigdataproject'  # Your MongoDB database name
mongo_collection_name = 'trades'  # Your MongoDB collection name

# Establish a connection to the MongoDB server
client = MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_pass,
    authSource='admin'  # The database that holds the user’s credentials
)

# Specify the database and collection
db = client[mongo_db_name]
collection = db[mongo_collection_name]

# Path to the JSON file
file_path = "/Users/priyasuresh/Documents/Documents_Priya’s MacBook Pro/SPRING2024/Data 228-Big Data/project/old_json/part-00008-29a4a8b3-8d0d-44c4-9709-e960b84b872c-c000.json"  # Replace with the path to your JSON file

# Function to load a JSON file into MongoDB
def load_json_file_to_mongodb(file_path):
    try:
        with open(file_path, 'r') as file:
            # Load each line as a separate JSON object
            for line in file:
                data = json.loads(line)
                collection.insert_one(data)
            print(f"Inserted data from {file_path} into MongoDB")
    except json.JSONDecodeError as e:
        print(f"Could not parse JSON from {file_path}: {e}")
    except Exception as e:
        print(f"Error inserting data from {file_path} into MongoDB: {e}")

# Load the file
load_json_file_to_mongodb(file_path)
# Out:
# Inserted data from /Users/priyasuresh/Documents/Documents_Priya’s MacBook Pro/SPRING2024/Data 228-Big Data/project/old_json/part-00008-29a4a8b3-8d0d-44c4-9709-e960b84b872c-c000.json into MongoDB

# %%
import json
import os
from pymongo import MongoClient

# MongoDB credentials and connection details
mongo_user = 'admin'
mongo_pass = 'Welcome@123'
mongo_host = 'localhost'
mongo_port = 27017
mongo_db_name = 'bigdataproject'
mongo_collection_name = 'trades'

# Establish a connection to the MongoDB server
client = MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_pass,
    authSource='admin'  # The database that holds the user’s credentials
)

# Specify the database and collection
db = client[mongo_db_name]
collection = db[mongo_collection_name]

# Directory containing JSON files
folder_path = "/Users/priyasuresh/Documents/Documents_Priya’s MacBook Pro/SPRING2024/Data 228-Big Data/project/old_json"

# Function to load all JSON files into MongoDB
def load_json_files_to_mongodb(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        collection.insert_one(data)
                print(f"Inserted data from {filename} into MongoDB")
            except json.JSONDecodeError as e:
                print(f"Could not parse JSON from {file_path}: {e}")
            except Exception as e:
                print(f"Error inserting data from {file_path} into MongoDB: {e}")

# Load the JSON files
load_json_files_to_mongodb(folder_path)
# Out:
# Inserted data from part-00005-1cd699f9-4eee-4830-8ba9-792cdc322184-c000.json into MongoDB
# Inserted data from part-00007-61a47213-f05e-450f-a86c-8472b5396ad9-c000.json into MongoDB
# Inserted data from part-00009-4d04e201-1832-4504-9047-84ca804e4576-c000.json into MongoDB
# Inserted data from part-00006-7da5b2e2-4dde-4dd3-8a76-9f19a4c7ab66-c000.json into MongoDB
# Inserted data from part-00003-0463878b-3e9a-487c-9167-b75c55a01796-c000.json into MongoDB
# Inserted data from part-00000-b47bd179-82c4-4af9-b3ab-584b67e24b4e-c000.json into MongoDB
# Inserted data from part-00006-49d8df98-155c-490c-a26a-3db9799dc1fb-c000.json into MongoDB
# Inserted data from part-00008-1cd699f9-4eee-4830-8ba9-792cdc322184-c000.json into MongoDB
# Inserted data from part-00004-4d04e201-1832-4504-9047-84ca804e4576-c000.json into MongoDB
# Inserted data from part-00008-f3116c98-d350-4edd-8e74-8ebf3f410e3d-c000.json into MongoDB
# ...

# %%
#below is same script is above--included file removal after processing

# %%
import json
import os
from pymongo import MongoClient

# MongoDB credentials and connection details
mongo_user = 'admin'
mongo_pass = 'Welcome@123'
mongo_host = 'localhost'
mongo_port = 27017
mongo_db_name = 'bigdataproject'
mongo_collection_name = 'trades'

# Establish a connection to the MongoDB server
client = MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_pass,
    authSource='admin'  # The database that holds the user’s credentials
)

# Specify the database and collection
db = client[mongo_db_name]
collection = db[mongo_collection_name]

# Directory containing JSON files
folder_path = "/Users/priyasuresh/Documents/Documents_Priya’s MacBook Pro/SPRING2024/Data 228-Big Data/project/old_json"

# Function to load all JSON files into MongoDB and remove them afterward
def load_json_files_to_mongodb(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        collection.insert_one(data)
                    os.remove(file_path)  # Remove file after processing
                    print(f"Inserted data from {filename} into MongoDB and deleted file.")
            except json.JSONDecodeError as e:
                print(f"Could not parse JSON from {file_path}: {e}")
            except Exception as e:
                print(f"Error inserting data from {file_path} into MongoDB: {e}")

# Load the JSON files
load_json_files_to_mongodb(folder_path)
# Out:
# Inserted data from part-00005-1cd699f9-4eee-4830-8ba9-792cdc322184-c000.json into MongoDB and deleted file.
# Inserted data from part-00007-61a47213-f05e-450f-a86c-8472b5396ad9-c000.json into MongoDB and deleted file.
# Inserted data from part-00009-4d04e201-1832-4504-9047-84ca804e4576-c000.json into MongoDB and deleted file.
# Inserted data from part-00006-7da5b2e2-4dde-4dd3-8a76-9f19a4c7ab66-c000.json into MongoDB and deleted file.
# Inserted data from part-00003-0463878b-3e9a-487c-9167-b75c55a01796-c000.json into MongoDB and deleted file.
# Inserted data from part-00000-b47bd179-82c4-4af9-b3ab-584b67e24b4e-c000.json into MongoDB and deleted file.
# Inserted data from part-00006-49d8df98-155c-490c-a26a-3db9799dc1fb-c000.json into MongoDB and deleted file.
# Inserted data from part-00008-1cd699f9-4eee-4830-8ba9-792cdc322184-c000.json into MongoDB and deleted file.
# Inserted data from part-00004-4d04e201-1832-4504-9047-84ca804e4576-c000.json into MongoDB and deleted file.
# ...

# %% [markdown]
# ### Final Code to run

# %%
import json
import os
import time
from pymongo import MongoClient

# MongoDB credentials and connection details
mongo_user = 'admin'
mongo_pass = 'Welcome@123'
mongo_host = 'localhost'
mongo_port = 27017
mongo_db_name = 'bigdataproject'
mongo_collection_name = 'trades'

# Establish a connection to the MongoDB server
client = MongoClient(
    host=mongo_host,
    port=mongo_port,
    username=mongo_user,
    password=mongo_pass,
    authSource='admin'  # The database that holds the user’s credentials
)

# Specify the database and collection
db = client[mongo_db_name]
collection = db[mongo_collection_name]

# Directory containing JSON files
folder_path = "/Users/priyasuresh/Documents/Documents_Priya’s MacBook Pro/SPRING2024/Data 228-Big Data/project/old_json"

# Function to load all JSON files into MongoDB and remove them afterward
def load_json_files_to_mongodb(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        collection.insert_one(data)
                    os.remove(file_path)  # Remove file after processing
                    print(f"Inserted data from {filename} into MongoDB and deleted file.")
            except json.JSONDecodeError as e:
                print(f"Could not parse JSON from {file_path}: {e}")
            except Exception as e:
                print(f"Error inserting data from {file_path} into MongoDB: {e}")

# Continuous execution
try:
    while True:
        load_json_files_to_mongodb(folder_path)
        print("Sleeping for 5 minutes.")
        time.sleep(300)  # Sleep for 5 minutes
except KeyboardInterrupt:
    print("Stopped by user.")
# Out:
# Sleeping for 5 minutes.
# Inserted data from part-00068-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00065-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00030-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00025-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00028-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00070-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00002-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# Inserted data from part-00057-c69c1285-0ed8-43ba-8f24-ee369aa5435d-c000.json into MongoDB and deleted file.
# ...
